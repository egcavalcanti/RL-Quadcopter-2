# %% [markdown]
# # Project: Train a Quadcopter How to Fly
#
# Design an agent to fly a quadcopter, and then train it using a reinforcement learning algorithm of your choice!
#
# Try to apply the techniques you have learnt, but also feel free to come up with innovative ideas and test them.

# %% [markdown]
# ## Instructions
#
# Take a look at the files in the directory to better understand the structure of the project.
#
# - `task.py`: Define your task (environment) in this file.
# - `agents/`: Folder containing reinforcement learning agents.
#     - `policy_search.py`: A sample agent has been provided here.
#     - `agent.py`: Develop your agent here.
# - `physics_sim.py`: This file contains the simulator for the quadcopter.  **DO NOT MODIFY THIS FILE**.
#
# For this project, you will define your own task in `task.py`.  Although we have provided a example task to get you started, you are encouraged to change it.  Later in this notebook, you will learn more about how to amend this file.
#
# You will also design a reinforcement learning agent in `agent.py` to complete your chosen task.
#
# You are welcome to create any additional files to help you to organize your code.  For instance, you may find it useful to define a `model.py` file defining any needed neural network architectures.
#
# ## Controlling the Quadcopter
#
# We provide a sample agent in the code cell below to show you how to use the sim to control the quadcopter.  This agent is even simpler than the sample agent that you'll examine (in `agents/policy_search.py`) later in this notebook!
#
# The agent controls the quadcopter by setting the revolutions per second on each of its four rotors.  The provided agent in the `Basic_Agent` class below always selects a random action for each of the four rotors.  These four speeds are returned by the `act` method as a list of four floating-point numbers.
#
# For this project, the agent that you will implement in `agents/agent.py` will have a far more intelligent method for selecting actions!

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# Run the code cell below to have the agent select actions to control the quadcopter.
#
# Feel free to change the provided values of `runtime`, `init_pose`, `init_velocities`, and `init_angle_velocities` below to change the starting conditions of the quadcopter.
#
# The `labels` list below annotates statistics that are saved while running the simulation.  All of this information is saved in a text file `data.txt` and stored in the dictionary `results`.

# %%
# %load_ext autoreload
# %autoreload 2

import csv
import numpy as np
from task import SampleTask

# Modify the values below to give the quadcopter a different starting position.
runtime = 5.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = SampleTask(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %% [markdown]
# Run the code cell below to visualize how the position of the quadcopter evolved during the simulation.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# The next code cell visualizes the velocity of the quadcopter.

# %%
plt.plot(results['time'], results['x_velocity'], label='x_hat')
plt.plot(results['time'], results['y_velocity'], label='y_hat')
plt.plot(results['time'], results['z_velocity'], label='z_hat')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Next, you can plot the Euler angles (the rotation of the quadcopter over the $x$-, $y$-, and $z$-axes),

# %%
plt.plot(results['time'], results['phi'], label='phi')
plt.plot(results['time'], results['theta'], label='theta')
plt.plot(results['time'], results['psi'], label='psi')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# before plotting the velocities (in radians per second) corresponding to each of the Euler angles.

# %%
plt.plot(results['time'], results['phi_velocity'], label='phi_velocity')
plt.plot(results['time'], results['theta_velocity'], label='theta_velocity')
plt.plot(results['time'], results['psi_velocity'], label='psi_velocity')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Finally, you can use the code cell below to print the agent's choice of actions.

# %%
plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1 revolutions / second')
plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2 revolutions / second')
plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3 revolutions / second')
plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4 revolutions / second')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# When specifying a task, you will derive the environment state from the simulator.  Run the code cell below to print the values of the following variables at the end of the simulation:
# - `task.sim.pose` (the position of the quadcopter in ($x,y,z$) dimensions and the Euler angles),
# - `task.sim.v` (the velocity of the quadcopter in ($x,y,z$) dimensions), and
# - `task.sim.angular_v` (radians/second for each of the three Euler angles).

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)

# %% [markdown]
# In the sample task in `task.py`, we use the 6-dimensional pose of the quadcopter to construct the state of the environment at each timestep.  However, when amending the task for your purposes, you are welcome to expand the size of the state vector by including the velocity information.  You can use any combination of the pose, velocity, and angular velocity - feel free to tinker here, and construct the state to suit your task.
#
# ## The Task
#
# A sample task has been provided for you in `task.py`.  Open this file in a new window now.
#
# The `__init__()` method is used to initialize several variables that are needed to specify the task.
# - The simulator is initialized as an instance of the `PhysicsSim` class (from `physics_sim.py`).
# - Inspired by the methodology in the original DDPG paper, we make use of action repeats.  For each timestep of the agent, we step the simulation `action_repeats` timesteps.  If you are not familiar with action repeats, please read the **Results** section in [the DDPG paper](https://arxiv.org/abs/1509.02971).
# - We set the number of elements in the state vector.  For the sample task, we only work with the 6-dimensional pose information.  To set the size of the state (`state_size`), we must take action repeats into account.
# - The environment will always have a 4-dimensional action space, with one entry for each rotor (`action_size=4`). You can set the minimum (`action_low`) and maximum (`action_high`) values of each entry here.
# - The sample task in this provided file is for the agent to reach a target position.  We specify that target position as a variable.
#
# The `reset()` method resets the simulator.  The agent should call this method every time the episode ends.  You can see an example of this in the code cell below.
#
# The `step()` method is perhaps the most important.  It accepts the agent's choice of action `rotor_speeds`, which is used to prepare the next state to pass on to the agent.  Then, the reward is computed from `get_reward()`.  The episode is considered done if the time limit has been exceeded, or the quadcopter has travelled outside of the bounds of the simulation.
#
# In the next section, you will learn how to test the performance of an agent on this task.

# %% [markdown]
# ## The Agent
#
# The sample agent given in `agents/policy_search.py` uses a very simplistic linear policy to directly compute the action vector as a dot product of the state vector and a matrix of weights. Then, it randomly perturbs the parameters by adding some Gaussian noise, to produce a different policy. Based on the average reward obtained in each episode (`score`), it keeps track of the best set of parameters found so far, how the score is changing, and accordingly tweaks a scaling factor to widen or tighten the noise.
#
# Run the code cell below to see how the agent performs on the sample task.

# %%
import sys
import pandas as pd
from agents.policy_search import PolicySearch_Agent
from task import SampleTask

num_episodes = 250
target_pos = np.array([0., 0., 10.])
task = SampleTask(target_pos=target_pos)
agent = PolicySearch_Agent(task)

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
    sys.stdout.flush()

# %% [markdown]
# This agent should perform very poorly on this task.  And that's where you come in!

# %% [markdown]
# ## Define the Task, Design the Agent, and Train Your Agent!
#
# Amend `task.py` to specify a task of your choosing.  If you're unsure what kind of task to specify, you may like to teach your quadcopter to takeoff, hover in place, land softly, or reach a target pose.
#
# After specifying your task, use the sample agent in `agents/policy_search.py` as a template to define your own agent in `agents/agent.py`.  You can borrow whatever you need from the sample agent, including ideas on how you might modularize your code (using helper methods like `act()`, `learn()`, `reset_episode()`, etc.).
#
# Note that it is **highly unlikely** that the first agent and task that you specify will learn well.  You will likely have to tweak various hyperparameters and the reward function for your task until you arrive at reasonably good behavior.
#
# As you develop your agent, it's important to keep an eye on how it's performing. Use the code above as inspiration to build in a mechanism to log/save the total rewards obtained in each episode to file.  If the episode rewards are gradually increasing, this is an indication that your agent is learning.

# %% [markdown]
# ## Trial with MountainCarContinuous-v0
#
# As training the quadcopter proved to be an exceedling hard task, I have decided to first test my agent with a well-known task with clear benchmarks to achieve. To this end I have used OpenAI's MountainCarContinuous-v0 environment. The task is to move a car up a hill, with a reward of 100 when the task is achieved, and negative rewards proportional to the squares of each action taken. The actions can take continuous values in $[-1,1]$, and thus MountainCarContinuous-v0 is a good test-case for the quadcopter agent, although it has simpler physics.

# %%
# testing agent with Continuous Mountain Car game
# %load_ext autoreload
# %autoreload 2

import sys
import pandas as pd
import numpy as np
import math
from agents.agent import DDPG
from task import MountainCarContinuousTask
import matplotlib.pyplot as plt
# %matplotlib inline
import itertools

num_episodes = 500
gamma = 0.7
theta = 0.15
sigma = 0.2

task = MountainCarContinuousTask()
agent = DDPG(task, gamma, theta, sigma)

rewards_data = {x : [] for x in ['episode', 'total_reward', 'running_average', 'average_reward']}

best_total_reward = -math.inf
average_reward = 0
average_10 = 0

for i_episode in range(1, num_episodes+1):

    state = agent.reset_episode() # start a new episode
    total_reward = 0
    episode_steps = 0    

    while True:
        action = agent.act(state)
        task.env.render()
        next_state, reward, done = task.step(action)
        episode_steps += task.action_repeat
        total_reward += reward
        agent.step(action, reward, next_state, done)
        state = next_state

        if done:
            if total_reward > best_total_reward:
                best_total_reward = total_reward
            average_reward = (average_reward*(i_episode - 1) + total_reward)/i_episode        
            rewards_data['episode'].append(i_episode)
            rewards_data['total_reward'].append(total_reward)
            average_10 = sum(rewards_data['total_reward'][i_episode-10:i_episode])/10
            rewards_data['running_average'].append(average_10)
            rewards_data['average_reward'].append(average_reward)
            print("\rEpisode = {:4d}, total_reward = {:7.3f} (best = {:7.2f}), average_10 = {:7.2f}, average_reward = {:7.2f}, episode_steps = {:3d}".format(i_episode, total_reward, best_total_reward, average_10, average_reward, episode_steps))#, end="")
            break
    sys.stdout.flush()
#print("Gamma =", gamma, 'theta=', theta, 'sigma=', sigma)
#plt.plot(rewards_data['episode'], rewards_data['total_reward'])
#plt.plot(rewards_data['episode'], rewards_data['running_average'])
#plt.plot(rewards_data['episode'], rewards_data['average_reward'])
#plt.show()
task.env.close()
# Out:
# Using TensorFlow backend.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Episode =    1, total_reward = -17.498 (best =  -17.50), average_10 =   -1.75, average_reward =  -17.50, episode_steps = 999
# Episode =    2, total_reward =  84.979 (best =   84.98), average_10 =    6.75, average_reward =   33.74, episode_steps = 768
# Episode =    3, total_reward =  90.475 (best =   90.47), average_10 =   15.80, average_reward =   52.65, episode_steps = 360
# Episode =    4, total_reward =  71.789 (best =   90.47), average_10 =   22.97, average_reward =   57.44, episode_steps = 288
# Episode =    5, total_reward =   9.264 (best =   90.47), average_10 =   23.90, average_reward =   47.80, episode_steps = 897
# Episode =    6, total_reward = -110.869 (best =   90.47), average_10 =    6.07, average_reward =   21.36, episode_steps = 999
# Episode =    7, total_reward = -86.247 (best =   90.47), average_10 =  -18.79, average_reward =    5.98, episode_steps = 999
# Episode =  118, total_reward =  83.468 (best =   95.26), average_10 =   85.61, average_reward =   -5.68, episode_steps = 192
# Episode =  119, total_reward =  81.386 (best =   95.26), average_10 =   85.16, average_reward =   -4.95, episode_steps = 177
# Episode =  120, total_reward =  87.697 (best =   95.26), average_10 =   84.80, average_reward =   -4.18, episode_steps = 165
# Episode =  121, total_reward =  79.665 (best =   95.26), average_10 =   84.19, average_reward =   -3.49, episode_steps = 189
# Episode =  122, total_reward =  81.272 (best =   95.26), average_10 =   83.76, average_reward =   -2.79, episode_steps = 258
# Episode =  123, total_reward =  77.691 (best =   95.26), average_10 =   82.73, average_reward =   -2.14, episode_steps = 192
# Episode =  124, total_reward =  76.437 (best =   95.26), average_10 =   82.58, average_reward =   -1.50, episode_steps = 252
# Episode =  125, total_reward =  81.318 (best =   95.26), average_10 =   82.57, average_reward =   -0.84, episode_steps = 186
# Episode =  126, total_reward =  83.432 (best =   95.26), average_10 =   82.12, average_reward =   -0.17, episode_steps = 228
# Episode =  127, total_reward =  82.308 (best =   95.26), average_10 =   81.47, average_reward =    0.48, episode_steps = 138
# Episode =  128, total_reward =  82.199 (best =   95.26), average_10 =   81.34, average_reward =    1.11, episode_steps = 162
# Episode =  129, total_reward =  79.953 (best =   95.26), average_10 =   81.20, average_reward =    1.73, episode_steps = 213
# Episode =  130, total_reward =  85.069 (best =   95.26), average_10 =   80.93, average_reward =    2.37, episode_steps = 141
# Episode =  131, total_reward =  85.226 (best =   95.26), average_10 =   81.49, average_reward =    3.00, episode_steps = 144
# Episode =  132, total_reward =  88.552 (best =   95.26), average_10 =   82.22, average_reward =    3.65, episode_steps = 120
# Episode =  133, total_reward =  83.182 (best =   95.26), average_10 =   82.77, average_reward =    4.25, episode_steps = 180
# Episode =  134, total_reward =  86.956 (best =   95.26), average_10 =   83.82, average_reward =    4.86, episode_steps =  96
# Episode =  135, total_reward =  84.060 (best =   95.26), average_10 =   84.09, average_reward =    5.45, episode_steps = 174
# Episode =  136, total_reward =  86.535 (best =   95.26), average_10 =   84.40, average_reward =    6.05, episode_steps = 168
# Episode =  137, total_reward =  85.306 (best =   95.26), average_10 =   84.70, average_reward =    6.62, episode_steps = 153
# Episode =  138, total_reward =  80.993 (best =   95.26), average_10 =   84.58, average_reward =    7.16, episode_steps = 192
# Episode =  139, total_reward =  86.030 (best =   95.26), average_10 =   85.19, average_reward =    7.73, episode_steps = 171
# Episode =  140, total_reward =  79.145 (best =   95.26), average_10 =   84.60, average_reward =    8.24, episode_steps = 189
# Episode =  141, total_reward =  75.064 (best =   95.26), average_10 =   83.58, average_reward =    8.71, episode_steps = 186
# Episode =  142, total_reward =  89.770 (best =   95.26), average_10 =   83.70, average_reward =    9.29, episode_steps = 147
# Episode =  143, total_reward =  84.746 (best =   95.26), average_10 =   83.86, average_reward =    9.81, episode_steps = 165
# Episode =  144, total_reward =  79.767 (best =   95.26), average_10 =   83.14, average_reward =   10.30, episode_steps = 222
# Episode =  145, total_reward =  76.221 (best =   95.26), average_10 =   82.36, average_reward =   10.75, episode_steps = 138
# Episode =  146, total_reward =  85.819 (best =   95.26), average_10 =   82.29, average_reward =   11.27, episode_steps = 174
# Episode =  147, total_reward =  82.863 (best =   95.26), average_10 =   82.04, average_reward =   11.75, episode_steps = 171
# Episode =  148, total_reward =  86.569 (best =   95.26), average_10 =   82.60, average_reward =   12.26, episode_steps = 153
# Episode =  149, total_reward =  80.435 (best =   95.26), average_10 =   82.04, average_reward =   12.72, episode_steps = 228
# Episode =  150, total_reward =  89.547 (best =   95.26), average_10 =   83.08, average_reward =   13.23, episode_steps = 135
# Episode =  151, total_reward =  87.783 (best =   95.26), average_10 =   84.35, average_reward =   13.72, episode_steps = 144
# Episode =  152, total_reward =  81.029 (best =   95.26), average_10 =   83.48, average_reward =   14.17, episode_steps = 216
# Episode =  153, total_reward =  61.989 (best =   95.26), average_10 =   81.20, average_reward =   14.48, episode_steps = 348
# Episode =  154, total_reward =  78.076 (best =   95.26), average_10 =   81.03, average_reward =   14.89, episode_steps = 177
# Episode =  155, total_reward =  82.142 (best =   95.26), average_10 =   81.63, average_reward =   15.33, episode_steps = 141
# Episode =  156, total_reward =  81.513 (best =   95.26), average_10 =   81.19, average_reward =   15.75, episode_steps = 171
# Episode =  157, total_reward =  89.025 (best =   95.26), average_10 =   81.81, average_reward =   16.22, episode_steps = 126
# Episode =  158, total_reward =  82.829 (best =   95.26), average_10 =   81.44, average_reward =   16.64, episode_steps = 189
# Episode =  159, total_reward =  82.898 (best =   95.26), average_10 =   81.68, average_reward =   17.06, episode_steps = 171
# Episode =  160, total_reward =  82.876 (best =   95.26), average_10 =   81.02, average_reward =   17.47, episode_steps = 156
# Episode =  161, total_reward =  89.721 (best =   95.26), average_10 =   81.21, average_reward =   17.92, episode_steps =  93
# Episode =  162, total_reward =  80.227 (best =   95.26), average_10 =   81.13, average_reward =   18.30, episode_steps = 243
# Episode =  163, total_reward =  70.666 (best =   95.26), average_10 =   82.00, average_reward =   18.62, episode_steps = 273
# Episode =  164, total_reward =  85.411 (best =   95.26), average_10 =   82.73, average_reward =   19.03, episode_steps = 195
# Episode =  165, total_reward =  86.489 (best =   95.26), average_10 =   83.17, average_reward =   19.44, episode_steps = 216
# Episode =  166, total_reward =  87.291 (best =   95.26), average_10 =   83.74, average_reward =   19.85, episode_steps = 120
# Episode =  167, total_reward =  83.706 (best =   95.26), average_10 =   83.21, average_reward =   20.23, episode_steps = 147
# Episode =  168, total_reward =  83.968 (best =   95.26), average_10 =   83.33, average_reward =   20.61, episode_steps = 303
# Episode =  169, total_reward =  87.335 (best =   95.26), average_10 =   83.77, average_reward =   21.00, episode_steps = 180
# Episode =  170, total_reward =  86.637 (best =   95.26), average_10 =   84.15, average_reward =   21.39, episode_steps = 165
# Episode =  171, total_reward =  90.109 (best =   95.26), average_10 =   84.18, average_reward =   21.79, episode_steps = 144
# Episode =  172, total_reward =  80.550 (best =   95.26), average_10 =   84.22, average_reward =   22.13, episode_steps = 177
# Episode =  173, total_reward =  82.169 (best =   95.26), average_10 =   85.37, average_reward =   22.48, episode_steps = 183
# Episode =  174, total_reward =  79.524 (best =   95.26), average_10 =   84.78, average_reward =   22.81, episode_steps = 285
# Episode =  175, total_reward =  81.630 (best =   95.26), average_10 =   84.29, average_reward =   23.14, episode_steps = 237
# Episode =  176, total_reward =  74.187 (best =   95.26), average_10 =   82.98, average_reward =   23.43, episode_steps = 264
# Episode =  177, total_reward =  84.079 (best =   95.26), average_10 =   83.02, average_reward =   23.78, episode_steps = 117
# Episode =  178, total_reward =  86.630 (best =   95.26), average_10 =   83.29, average_reward =   24.13, episode_steps = 123
# Episode =  179, total_reward =  82.360 (best =   95.26), average_10 =   82.79, average_reward =   24.45, episode_steps = 123
# Episode =  180, total_reward =  88.160 (best =   95.26), average_10 =   82.94, average_reward =   24.81, episode_steps = 114
# Episode =  181, total_reward =  84.489 (best =   95.26), average_10 =   82.38, average_reward =   25.14, episode_steps = 168
# Episode =  182, total_reward =  82.290 (best =   95.26), average_10 =   82.55, average_reward =   25.45, episode_steps = 246
# Episode =  183, total_reward =  88.418 (best =   95.26), average_10 =   83.18, average_reward =   25.80, episode_steps = 123
# Episode =  184, total_reward =  82.899 (best =   95.26), average_10 =   83.51, average_reward =   26.11, episode_steps = 156
# Episode =  185, total_reward =  77.377 (best =   95.26), average_10 =   83.09, average_reward =   26.38, episode_steps = 309
# Episode =  186, total_reward = -30.439 (best =   95.26), average_10 =   72.63, average_reward =   26.08, episode_steps = 999
# Episode =  187, total_reward =  83.626 (best =   95.26), average_10 =   72.58, average_reward =   26.39, episode_steps = 171
# Episode =  188, total_reward =  84.489 (best =   95.26), average_10 =   72.37, average_reward =   26.69, episode_steps = 138
# Episode =  189, total_reward =  79.019 (best =   95.26), average_10 =   72.03, average_reward =   26.97, episode_steps = 213
# Episode =  190, total_reward = -35.807 (best =   95.26), average_10 =   59.64, average_reward =   26.64, episode_steps = 999
# Episode =  191, total_reward =  79.360 (best =   95.26), average_10 =   59.12, average_reward =   26.92, episode_steps = 162
# Episode =  192, total_reward =  85.784 (best =   95.26), average_10 =   59.47, average_reward =   27.22, episode_steps = 165
# Episode =  193, total_reward =  80.744 (best =   95.26), average_10 =   58.71, average_reward =   27.50, episode_steps = 408
# Episode =  194, total_reward =  90.663 (best =   95.26), average_10 =   59.48, average_reward =   27.83, episode_steps = 117
# Episode =  195, total_reward =  83.425 (best =   95.26), average_10 =   60.09, average_reward =   28.11, episode_steps = 186
# Episode =  196, total_reward =  72.972 (best =   95.26), average_10 =   70.43, average_reward =   28.34, episode_steps = 486
# Episode =  197, total_reward =  88.470 (best =   95.26), average_10 =   70.91, average_reward =   28.65, episode_steps = 126
# Episode =  198, total_reward =  72.467 (best =   95.26), average_10 =   69.71, average_reward =   28.87, episode_steps = 339
# Episode =  199, total_reward =  90.931 (best =   95.26), average_10 =   70.90, average_reward =   29.18, episode_steps = 135
# Episode =  200, total_reward =  85.963 (best =   95.26), average_10 =   83.08, average_reward =   29.46, episode_steps = 117
# Episode =  201, total_reward =  82.789 (best =   95.26), average_10 =   83.42, average_reward =   29.73, episode_steps = 123
# Episode =  202, total_reward =  74.371 (best =   95.26), average_10 =   82.28, average_reward =   29.95, episode_steps = 387
# Episode =  203, total_reward =  76.543 (best =   95.26), average_10 =   81.86, average_reward =   30.18, episode_steps = 207
# Episode =  204, total_reward =  86.643 (best =   95.26), average_10 =   81.46, average_reward =   30.46, episode_steps = 156
# Episode =  205, total_reward =  87.147 (best =   95.26), average_10 =   81.83, average_reward =   30.73, episode_steps = 114
# Episode =  206, total_reward =  64.047 (best =   95.26), average_10 =   80.94, average_reward =   30.89, episode_steps = 642
# Episode =  207, total_reward =  75.345 (best =   95.26), average_10 =   79.62, average_reward =   31.11, episode_steps = 237
# Episode =  208, total_reward =  82.476 (best =   95.26), average_10 =   80.63, average_reward =   31.36, episode_steps = 159
# Episode =  209, total_reward =  83.639 (best =   95.26), average_10 =   79.90, average_reward =   31.61, episode_steps = 201
# Episode =  210, total_reward =  88.077 (best =   95.26), average_10 =   80.11, average_reward =   31.87, episode_steps = 108
# Episode =  211, total_reward =  73.355 (best =   95.26), average_10 =   79.16, average_reward =   32.07, episode_steps = 333
# Episode =  212, total_reward =  84.011 (best =   95.26), average_10 =   80.13, average_reward =   32.32, episode_steps = 216
# Episode =  213, total_reward =  79.714 (best =   95.26), average_10 =   80.45, average_reward =   32.54, episode_steps = 222
# Episode =  214, total_reward =  76.449 (best =   95.26), average_10 =   79.43, average_reward =   32.74, episode_steps = 609
# Episode =  215, total_reward =  81.336 (best =   95.26), average_10 =   78.84, average_reward =   32.97, episode_steps = 249
# Episode =  216, total_reward =  68.329 (best =   95.26), average_10 =   79.27, average_reward =   33.13, episode_steps = 525
# Episode =  217, total_reward =  86.363 (best =   95.26), average_10 =   80.37, average_reward =   33.38, episode_steps = 120
# Episode =  218, total_reward =  81.513 (best =   95.26), average_10 =   80.28, average_reward =   33.60, episode_steps = 315
# Episode =  219, total_reward =  87.904 (best =   95.26), average_10 =   80.71, average_reward =   33.85, episode_steps =  99
# Episode =  220, total_reward =  85.496 (best =   95.26), average_10 =   80.45, average_reward =   34.08, episode_steps = 114
# Episode =  221, total_reward =  82.566 (best =   95.26), average_10 =   81.37, average_reward =   34.30, episode_steps = 231
# Episode =  222, total_reward =  80.832 (best =   95.26), average_10 =   81.05, average_reward =   34.51, episode_steps = 246
# Episode =  223, total_reward =  71.519 (best =   95.26), average_10 =   80.23, average_reward =   34.68, episode_steps = 420
# Episode =  224, total_reward =  87.106 (best =   95.26), average_10 =   81.30, average_reward =   34.91, episode_steps = 102
# Episode =  225, total_reward =  88.006 (best =   95.26), average_10 =   81.96, average_reward =   35.15, episode_steps = 168
# Episode =  226, total_reward =  87.496 (best =   95.26), average_10 =   83.88, average_reward =   35.38, episode_steps = 216
# Episode =  227, total_reward =  77.987 (best =   95.26), average_10 =   83.04, average_reward =   35.57, episode_steps = 291
# Episode =  228, total_reward =  82.402 (best =   95.26), average_10 =   83.13, average_reward =   35.77, episode_steps = 117
# Episode =  229, total_reward =  89.336 (best =   95.26), average_10 =   83.27, average_reward =   36.01, episode_steps = 132
# Episode =  230, total_reward =  73.890 (best =   95.26), average_10 =   82.11, average_reward =   36.17, episode_steps = 330
# Episode =  231, total_reward =  88.589 (best =   95.26), average_10 =   82.72, average_reward =   36.40, episode_steps = 183
# Episode =  232, total_reward =  76.028 (best =   95.26), average_10 =   82.24, average_reward =   36.57, episode_steps = 201
# Episode =  233, total_reward =  74.462 (best =   95.26), average_10 =   82.53, average_reward =   36.73, episode_steps = 237
# Episode =  234, total_reward =  87.947 (best =   95.26), average_10 =   82.61, average_reward =   36.95, episode_steps = 171
# Episode =  235, total_reward =  85.525 (best =   95.26), average_10 =   82.37, average_reward =   37.16, episode_steps = 399
# Episode =  236, total_reward =  88.819 (best =   95.26), average_10 =   82.50, average_reward =   37.38, episode_steps = 126
# Episode =  237, total_reward =  90.750 (best =   95.26), average_10 =   83.77, average_reward =   37.60, episode_steps = 165
# Episode =  238, total_reward =  80.249 (best =   95.26), average_10 =   83.56, average_reward =   37.78, episode_steps = 654
# Episode =  239, total_reward =  84.895 (best =   95.26), average_10 =   83.12, average_reward =   37.98, episode_steps = 405
# Episode =  240, total_reward =  84.226 (best =   95.26), average_10 =   84.15, average_reward =   38.17, episode_steps = 555
# Episode =  241, total_reward =  89.742 (best =   95.26), average_10 =   84.26, average_reward =   38.38, episode_steps = 318
# Episode =  242, total_reward =  85.237 (best =   95.26), average_10 =   85.19, average_reward =   38.58, episode_steps = 300
# Episode =  243, total_reward =  70.658 (best =   95.26), average_10 =   84.80, average_reward =   38.71, episode_steps = 780
# Episode =  244, total_reward =  71.665 (best =   95.26), average_10 =   83.18, average_reward =   38.84, episode_steps = 549
# Episode =  245, total_reward =  75.589 (best =   95.26), average_10 =   82.18, average_reward =   38.99, episode_steps = 480
# Episode =  246, total_reward =  77.799 (best =   95.26), average_10 =   81.08, average_reward =   39.15, episode_steps = 375
# Episode =  247, total_reward =  74.258 (best =   95.26), average_10 =   79.43, average_reward =   39.29, episode_steps = 459
# Episode =  248, total_reward =  86.763 (best =   95.26), average_10 =   80.08, average_reward =   39.49, episode_steps = 252
# Episode =  249, total_reward =  74.806 (best =   95.26), average_10 =   79.07, average_reward =   39.63, episode_steps = 309
# Episode =  250, total_reward =  61.657 (best =   95.26), average_10 =   76.82, average_reward =   39.72, episode_steps = 567
# Episode =  251, total_reward =  66.273 (best =   95.26), average_10 =   74.47, average_reward =   39.82, episode_steps = 420
# Episode =  252, total_reward =  74.822 (best =   95.26), average_10 =   73.43, average_reward =   39.96, episode_steps = 330
# Episode =  253, total_reward =  39.618 (best =   95.26), average_10 =   70.33, average_reward =   39.96, episode_steps = 777
# Episode =  254, total_reward =  40.703 (best =   95.26), average_10 =   67.23, average_reward =   39.96, episode_steps = 729
# Episode =  255, total_reward =  78.022 (best =   95.26), average_10 =   67.47, average_reward =   40.11, episode_steps = 219
# Episode =  256, total_reward =  73.630 (best =   95.26), average_10 =   67.06, average_reward =   40.24, episode_steps = 357
# Episode =  257, total_reward =  52.119 (best =   95.26), average_10 =   64.84, average_reward =   40.29, episode_steps = 480
# Episode =  258, total_reward = -90.933 (best =   95.26), average_10 =   47.07, average_reward =   39.78, episode_steps = 999
# Episode =  259, total_reward =  52.332 (best =   95.26), average_10 =   44.82, average_reward =   39.83, episode_steps = 531
# Episode =  260, total_reward =  31.496 (best =   95.26), average_10 =   41.81, average_reward =   39.80, episode_steps = 744
# Episode =  261, total_reward = -95.604 (best =   95.26), average_10 =   25.62, average_reward =   39.28, episode_steps = 999
# Episode =  262, total_reward =  50.334 (best =   95.26), average_10 =   23.17, average_reward =   39.32, episode_steps = 507
# Episode =  263, total_reward =  55.242 (best =   95.26), average_10 =   24.73, average_reward =   39.38, episode_steps = 441
# Episode =  264, total_reward =  72.075 (best =   95.26), average_10 =   27.87, average_reward =   39.50, episode_steps = 273
# Episode =  265, total_reward =  37.798 (best =   95.26), average_10 =   23.85, average_reward =   39.50, episode_steps = 651
# Episode =  266, total_reward = -99.495 (best =   95.26), average_10 =    6.54, average_reward =   38.98, episode_steps = 999
# Episode =  267, total_reward =  36.112 (best =   95.26), average_10 =    4.94, average_reward =   38.96, episode_steps = 627
# Episode =  268, total_reward = -101.897 (best =   95.26), average_10 =    3.84, average_reward =   38.44, episode_steps = 999
# Episode =  269, total_reward =  40.032 (best =   95.26), average_10 =    2.61, average_reward =   38.44, episode_steps = 519
# Episode =  270, total_reward = -102.259 (best =   95.26), average_10 =  -10.77, average_reward =   37.92, episode_steps = 999
# Episode =  271, total_reward =   2.995 (best =   95.26), average_10 =   -0.91, average_reward =   37.79, episode_steps = 921
# Episode =  272, total_reward =  66.337 (best =   95.26), average_10 =    0.69, average_reward =   37.90, episode_steps = 336
# Episode =  273, total_reward =  19.645 (best =   95.26), average_10 =   -2.87, average_reward =   37.83, episode_steps = 792
# Episode =  274, total_reward = -102.245 (best =   95.26), average_10 =  -20.30, average_reward =   37.32, episode_steps = 999
# Episode =  275, total_reward =  10.000 (best =   95.26), average_10 =  -23.08, average_reward =   37.22, episode_steps = 888
# Episode =  276, total_reward =  61.833 (best =   95.26), average_10 =   -6.94, average_reward =   37.31, episode_steps = 390
# Episode =  277, total_reward =  49.240 (best =   95.26), average_10 =   -5.63, average_reward =   37.35, episode_steps = 474
# Episode =  278, total_reward =  42.302 (best =   95.26), average_10 =    8.79, average_reward =   37.37, episode_steps = 573
# Episode =  279, total_reward =  12.284 (best =   95.26), average_10 =    6.01, average_reward =   37.28, episode_steps = 828
# Episode =  280, total_reward =  18.506 (best =   95.26), average_10 =   18.09, average_reward =   37.22, episode_steps = 753
# Episode =  281, total_reward =   7.457 (best =   95.26), average_10 =   18.54, average_reward =   37.11, episode_steps = 882
# Episode =  282, total_reward = -102.258 (best =   95.26), average_10 =    1.68, average_reward =   36.62, episode_steps = 999
# Episode =  283, total_reward =   0.926 (best =   95.26), average_10 =   -0.20, average_reward =   36.49, episode_steps = 927
# Episode =  284, total_reward =  40.542 (best =   95.26), average_10 =   14.08, average_reward =   36.50, episode_steps = 552
# Episode =  285, total_reward = -106.083 (best =   95.26), average_10 =    2.47, average_reward =   36.00, episode_steps = 999
# Episode =  286, total_reward = -95.864 (best =   95.26), average_10 =  -13.29, average_reward =   35.54, episode_steps = 999
# Episode =  287, total_reward =   3.382 (best =   95.26), average_10 =  -17.88, average_reward =   35.43, episode_steps = 879
# Episode =  288, total_reward = -106.647 (best =   95.26), average_10 =  -32.78, average_reward =   34.94, episode_steps = 999
# Episode =  289, total_reward = -104.629 (best =   95.26), average_10 =  -44.47, average_reward =   34.45, episode_steps = 999
# Episode =  290, total_reward = -105.708 (best =   95.26), average_10 =  -56.89, average_reward =   33.97, episode_steps = 999
# Episode =  291, total_reward =  21.177 (best =   95.26), average_10 =  -55.52, average_reward =   33.93, episode_steps = 810
# Episode =  292, total_reward =  29.280 (best =   95.26), average_10 =  -42.36, average_reward =   33.91, episode_steps = 684
# Episode =  293, total_reward =  39.152 (best =   95.26), average_10 =  -38.54, average_reward =   33.93, episode_steps = 624
# Episode =  294, total_reward =  -1.569 (best =   95.26), average_10 =  -42.75, average_reward =   33.81, episode_steps = 921
# Episode =  295, total_reward =  37.523 (best =   95.26), average_10 =  -28.39, average_reward =   33.82, episode_steps = 657
# Episode =  296, total_reward =  44.152 (best =   95.26), average_10 =  -14.39, average_reward =   33.86, episode_steps = 543
# Episode =  297, total_reward = -105.740 (best =   95.26), average_10 =  -25.30, average_reward =   33.39, episode_steps = 999
# Episode =  298, total_reward = -108.627 (best =   95.26), average_10 =  -25.50, average_reward =   32.91, episode_steps = 999
# Episode =  299, total_reward = -101.999 (best =   95.26), average_10 =  -25.24, average_reward =   32.46, episode_steps = 999
# Episode =  300, total_reward =  65.677 (best =   95.26), average_10 =   -8.10, average_reward =   32.57, episode_steps = 297
# Episode =  301, total_reward =   2.728 (best =   95.26), average_10 =   -9.94, average_reward =   32.47, episode_steps = 891
# Episode =  302, total_reward =   1.834 (best =   95.26), average_10 =  -12.69, average_reward =   32.37, episode_steps = 891
# Episode =  303, total_reward =  45.131 (best =   95.26), average_10 =  -12.09, average_reward =   32.41, episode_steps = 528
# Episode =  304, total_reward =  64.271 (best =   95.26), average_10 =   -5.51, average_reward =   32.51, episode_steps = 339
# Episode =  305, total_reward =  33.755 (best =   95.26), average_10 =   -5.88, average_reward =   32.52, episode_steps = 693
# Episode =  306, total_reward = -108.143 (best =   95.26), average_10 =  -21.11, average_reward =   32.06, episode_steps = 999
# Episode =  307, total_reward =  41.593 (best =   95.26), average_10 =   -6.38, average_reward =   32.09, episode_steps = 558
# Episode =  308, total_reward = -102.553 (best =   95.26), average_10 =   -5.77, average_reward =   31.65, episode_steps = 999
# Episode =  309, total_reward =  24.888 (best =   95.26), average_10 =    6.92, average_reward =   31.63, episode_steps = 729
# Episode =  310, total_reward =  20.615 (best =   95.26), average_10 =    2.41, average_reward =   31.60, episode_steps = 729
# Episode =  311, total_reward =  71.671 (best =   95.26), average_10 =    9.31, average_reward =   31.72, episode_steps = 252
# Episode =  312, total_reward =   7.621 (best =   95.26), average_10 =    9.88, average_reward =   31.65, episode_steps = 876
# Episode =  313, total_reward =  35.419 (best =   95.26), average_10 =    8.91, average_reward =   31.66, episode_steps = 639
# Episode =  314, total_reward =  55.801 (best =   95.26), average_10 =    8.07, average_reward =   31.74, episode_steps = 429
# Episode =  315, total_reward =  60.109 (best =   95.26), average_10 =   10.70, average_reward =   31.83, episode_steps = 471
# Episode =  316, total_reward =  44.560 (best =   95.26), average_10 =   25.97, average_reward =   31.87, episode_steps = 528
# Episode =  317, total_reward =  68.939 (best =   95.26), average_10 =   28.71, average_reward =   31.98, episode_steps = 309
# Episode =  318, total_reward =  76.323 (best =   95.26), average_10 =   46.59, average_reward =   32.12, episode_steps = 237
# Episode =  319, total_reward =  77.981 (best =   95.26), average_10 =   51.90, average_reward =   32.27, episode_steps = 174
# Episode =  320, total_reward =  77.921 (best =   95.26), average_10 =   57.63, average_reward =   32.41, episode_steps = 240
# Episode =  321, total_reward =  84.967 (best =   95.26), average_10 =   58.96, average_reward =   32.57, episode_steps = 114
# Episode =  322, total_reward =  76.068 (best =   95.26), average_10 =   65.81, average_reward =   32.71, episode_steps = 234
# Episode =  323, total_reward =  77.031 (best =   95.26), average_10 =   69.97, average_reward =   32.85, episode_steps = 225
# Episode =  324, total_reward =  80.150 (best =   95.26), average_10 =   72.40, average_reward =   32.99, episode_steps = 171
# Episode =  325, total_reward =  85.849 (best =   95.26), average_10 =   74.98, average_reward =   33.15, episode_steps = 168
# Episode =  326, total_reward =  75.801 (best =   95.26), average_10 =   78.10, average_reward =   33.28, episode_steps = 189
# Episode =  327, total_reward =  76.405 (best =   95.26), average_10 =   78.85, average_reward =   33.42, episode_steps = 159
# Episode =  328, total_reward =  83.622 (best =   95.26), average_10 =   79.58, average_reward =   33.57, episode_steps = 174
# Episode =  329, total_reward =  85.455 (best =   95.26), average_10 =   80.33, average_reward =   33.73, episode_steps = 126
# Episode =  330, total_reward =  88.335 (best =   95.26), average_10 =   81.37, average_reward =   33.89, episode_steps = 171
# Episode =  331, total_reward =  83.161 (best =   95.26), average_10 =   81.19, average_reward =   34.04, episode_steps = 168
# Episode =  332, total_reward =  78.763 (best =   95.26), average_10 =   81.46, average_reward =   34.18, episode_steps = 180
# Episode =  333, total_reward =  83.996 (best =   95.26), average_10 =   82.15, average_reward =   34.33, episode_steps = 210
# Episode =  334, total_reward =  77.946 (best =   95.26), average_10 =   81.93, average_reward =   34.46, episode_steps = 195
# Episode =  335, total_reward =  77.281 (best =   95.26), average_10 =   81.08, average_reward =   34.58, episode_steps = 231
# Episode =  336, total_reward =  73.737 (best =   95.26), average_10 =   80.87, average_reward =   34.70, episode_steps = 243
# Episode =  337, total_reward =  46.917 (best =   95.26), average_10 =   77.92, average_reward =   34.74, episode_steps = 513
# Episode =  338, total_reward =  85.867 (best =   95.26), average_10 =   78.15, average_reward =   34.89, episode_steps = 168
# Episode =  339, total_reward =  85.631 (best =   95.26), average_10 =   78.16, average_reward =   35.04, episode_steps = 165
# Episode =  340, total_reward =  85.937 (best =   95.26), average_10 =   77.92, average_reward =   35.19, episode_steps = 156
# Episode =  341, total_reward =  89.514 (best =   95.26), average_10 =   78.56, average_reward =   35.35, episode_steps = 108
# Episode =  342, total_reward =  86.854 (best =   95.26), average_10 =   79.37, average_reward =   35.50, episode_steps = 114
# Episode =  343, total_reward =  63.839 (best =   95.26), average_10 =   77.35, average_reward =   35.58, episode_steps = 429
# Episode =  344, total_reward =  73.454 (best =   95.26), average_10 =   76.90, average_reward =   35.69, episode_steps = 210
# Episode =  345, total_reward =  71.939 (best =   95.26), average_10 =   76.37, average_reward =   35.80, episode_steps = 237
# Episode =  346, total_reward =  83.844 (best =   95.26), average_10 =   77.38, average_reward =   35.93, episode_steps = 189
# Episode =  347, total_reward =  83.509 (best =   95.26), average_10 =   81.04, average_reward =   36.07, episode_steps = 171
# Episode =  348, total_reward =  83.042 (best =   95.26), average_10 =   80.76, average_reward =   36.21, episode_steps = 159
# Episode =  349, total_reward =  84.352 (best =   95.26), average_10 =   80.63, average_reward =   36.34, episode_steps = 120
# Episode =  350, total_reward =  83.927 (best =   95.26), average_10 =   80.43, average_reward =   36.48, episode_steps = 165
# Episode =  351, total_reward =  76.797 (best =   95.26), average_10 =   79.16, average_reward =   36.60, episode_steps = 315
# Episode =  352, total_reward =  83.153 (best =   95.26), average_10 =   78.79, average_reward =   36.73, episode_steps = 177
# Episode =  353, total_reward =  85.140 (best =   95.26), average_10 =   80.92, average_reward =   36.86, episode_steps = 180
# Episode =  354, total_reward =  77.701 (best =   95.26), average_10 =   81.34, average_reward =   36.98, episode_steps = 258
# Episode =  355, total_reward =  72.253 (best =   95.26), average_10 =   81.37, average_reward =   37.08, episode_steps = 303
# Episode =  356, total_reward =  79.797 (best =   95.26), average_10 =   80.97, average_reward =   37.20, episode_steps = 156
# Episode =  357, total_reward =  81.659 (best =   95.26), average_10 =   80.78, average_reward =   37.32, episode_steps = 174
# Episode =  358, total_reward =  76.366 (best =   95.26), average_10 =   80.11, average_reward =   37.43, episode_steps = 330
# Episode =  359, total_reward =  84.621 (best =   95.26), average_10 =   80.14, average_reward =   37.56, episode_steps = 183
# Episode =  360, total_reward =  85.813 (best =   95.26), average_10 =   80.33, average_reward =   37.70, episode_steps = 168
# Episode =  361, total_reward =  77.225 (best =   95.26), average_10 =   80.37, average_reward =   37.81, episode_steps = 231
# Episode =  362, total_reward =  90.082 (best =   95.26), average_10 =   81.07, average_reward =   37.95, episode_steps = 108
# Episode =  363, total_reward =  79.356 (best =   95.26), average_10 =   80.49, average_reward =   38.07, episode_steps = 180
# Episode =  364, total_reward =  84.618 (best =   95.26), average_10 =   81.18, average_reward =   38.19, episode_steps = 192
# Episode =  365, total_reward =  83.959 (best =   95.26), average_10 =   82.35, average_reward =   38.32, episode_steps = 165
# Episode =  366, total_reward =  80.797 (best =   95.26), average_10 =   82.45, average_reward =   38.44, episode_steps = 225
# Episode =  367, total_reward =  83.741 (best =   95.26), average_10 =   82.66, average_reward =   38.56, episode_steps = 180
# Episode =  368, total_reward =  75.760 (best =   95.26), average_10 =   82.60, average_reward =   38.66, episode_steps = 267
# Episode =  369, total_reward =  84.146 (best =   95.26), average_10 =   82.55, average_reward =   38.78, episode_steps = 168
# Episode =  370, total_reward =  85.940 (best =   95.26), average_10 =   82.56, average_reward =   38.91, episode_steps = 144
# Episode =  371, total_reward =  85.716 (best =   95.26), average_10 =   83.41, average_reward =   39.04, episode_steps = 132
# Episode =  372, total_reward =  80.783 (best =   95.26), average_10 =   82.48, average_reward =   39.15, episode_steps = 171
# Episode =  373, total_reward =  78.996 (best =   95.26), average_10 =   82.45, average_reward =   39.26, episode_steps = 174
# Episode =  374, total_reward =  89.751 (best =   95.26), average_10 =   82.96, average_reward =   39.39, episode_steps = 117
# Episode =  375, total_reward =  75.293 (best =   95.26), average_10 =   82.09, average_reward =   39.49, episode_steps = 231
# Episode =  376, total_reward =  87.963 (best =   95.26), average_10 =   82.81, average_reward =   39.62, episode_steps = 180
# Episode =  377, total_reward =  82.412 (best =   95.26), average_10 =   82.68, average_reward =   39.73, episode_steps = 246
# Episode =  378, total_reward =  64.363 (best =   95.26), average_10 =   81.54, average_reward =   39.79, episode_steps = 291
# Episode =  379, total_reward =  70.753 (best =   95.26), average_10 =   80.20, average_reward =   39.88, episode_steps = 327
# Episode =  380, total_reward =  66.946 (best =   95.26), average_10 =   78.30, average_reward =   39.95, episode_steps = 267
# Episode =  381, total_reward =  77.091 (best =   95.26), average_10 =   77.44, average_reward =   40.04, episode_steps = 264
# Episode =  382, total_reward =  75.785 (best =   95.26), average_10 =   76.94, average_reward =   40.14, episode_steps = 249
# Episode =  383, total_reward =  84.311 (best =   95.26), average_10 =   77.47, average_reward =   40.25, episode_steps = 234
# Episode =  384, total_reward =  80.779 (best =   95.26), average_10 =   76.57, average_reward =   40.36, episode_steps = 267
# Episode =  385, total_reward =  68.903 (best =   95.26), average_10 =   75.93, average_reward =   40.43, episode_steps = 195
# Episode =  386, total_reward =  83.673 (best =   95.26), average_10 =   75.50, average_reward =   40.55, episode_steps = 183
# Episode =  387, total_reward =  74.971 (best =   95.26), average_10 =   74.76, average_reward =   40.63, episode_steps = 237
# Episode =  388, total_reward =  82.856 (best =   95.26), average_10 =   76.61, average_reward =   40.74, episode_steps = 216
# Episode =  389, total_reward =  62.149 (best =   95.26), average_10 =   75.75, average_reward =   40.80, episode_steps = 309
# Episode =  390, total_reward =  83.458 (best =   95.26), average_10 =   77.40, average_reward =   40.91, episode_steps = 246
# Episode =  391, total_reward =  83.795 (best =   95.26), average_10 =   78.07, average_reward =   41.02, episode_steps = 162
# Episode =  392, total_reward =  83.827 (best =   95.26), average_10 =   78.87, average_reward =   41.13, episode_steps = 240
# Episode =  393, total_reward =  65.304 (best =   95.26), average_10 =   76.97, average_reward =   41.19, episode_steps = 246
# Episode =  394, total_reward =  77.211 (best =   95.26), average_10 =   76.61, average_reward =   41.28, episode_steps = 213
# Episode =  395, total_reward =  63.355 (best =   95.26), average_10 =   76.06, average_reward =   41.34, episode_steps = 390
# Episode =  396, total_reward =  78.606 (best =   95.26), average_10 =   75.55, average_reward =   41.43, episode_steps = 270
# Episode =  397, total_reward =  86.038 (best =   95.26), average_10 =   76.66, average_reward =   41.54, episode_steps = 177
# Episode =  398, total_reward =  86.415 (best =   95.26), average_10 =   77.02, average_reward =   41.65, episode_steps = 168
# Episode =  399, total_reward =  83.150 (best =   95.26), average_10 =   79.12, average_reward =   41.76, episode_steps = 168
# Episode =  400, total_reward =  82.973 (best =   95.26), average_10 =   79.07, average_reward =   41.86, episode_steps = 273
# Episode =  401, total_reward =  84.852 (best =   95.26), average_10 =   79.17, average_reward =   41.97, episode_steps = 168
# Episode =  402, total_reward =  83.802 (best =   95.26), average_10 =   79.17, average_reward =   42.07, episode_steps = 165
# Episode =  403, total_reward =  79.233 (best =   95.26), average_10 =   80.56, average_reward =   42.17, episode_steps = 261
# Episode =  404, total_reward =  79.155 (best =   95.26), average_10 =   80.76, average_reward =   42.26, episode_steps = 174
# Episode =  405, total_reward =  86.496 (best =   95.26), average_10 =   83.07, average_reward =   42.37, episode_steps = 165
# Episode =  406, total_reward =  51.327 (best =   95.26), average_10 =   80.34, average_reward =   42.39, episode_steps = 582
# Episode =  407, total_reward =  79.486 (best =   95.26), average_10 =   79.69, average_reward =   42.48, episode_steps = 225
# Episode =  408, total_reward =  63.527 (best =   95.26), average_10 =   77.40, average_reward =   42.53, episode_steps = 438
# Episode =  409, total_reward =  73.235 (best =   95.26), average_10 =   76.41, average_reward =   42.61, episode_steps = 339
# Episode =  410, total_reward =  81.500 (best =   95.26), average_10 =   76.26, average_reward =   42.70, episode_steps = 171
# Episode =  411, total_reward =  74.268 (best =   95.26), average_10 =   75.20, average_reward =   42.78, episode_steps = 306
# Episode =  412, total_reward =  75.206 (best =   95.26), average_10 =   74.34, average_reward =   42.86, episode_steps = 321
# Episode =  413, total_reward =  55.928 (best =   95.26), average_10 =   72.01, average_reward =   42.89, episode_steps = 504
# Episode =  414, total_reward =  66.266 (best =   95.26), average_10 =   70.72, average_reward =   42.94, episode_steps = 351
# Episode =  415, total_reward =  61.217 (best =   95.26), average_10 =   68.20, average_reward =   42.99, episode_steps = 453
# Episode =  416, total_reward =  80.429 (best =   95.26), average_10 =   71.11, average_reward =   43.08, episode_steps = 192
# Episode =  417, total_reward =  92.646 (best =   95.26), average_10 =   72.42, average_reward =   43.20, episode_steps =  72
# Episode =  418, total_reward =  91.554 (best =   95.26), average_10 =   75.22, average_reward =   43.31, episode_steps =  81
# Episode =  419, total_reward =  85.359 (best =   95.26), average_10 =   76.44, average_reward =   43.41, episode_steps = 144
# Episode =  420, total_reward =  78.428 (best =   95.26), average_10 =   76.13, average_reward =   43.50, episode_steps = 216
# Episode =  421, total_reward =  80.832 (best =   95.26), average_10 =   76.79, average_reward =   43.59, episode_steps = 147
# Episode =  422, total_reward =  77.496 (best =   95.26), average_10 =   77.02, average_reward =   43.67, episode_steps = 285
# Episode =  423, total_reward =  89.599 (best =   95.26), average_10 =   80.38, average_reward =   43.77, episode_steps = 147
# Episode =  424, total_reward =  85.458 (best =   95.26), average_10 =   82.30, average_reward =   43.87, episode_steps = 132
# Episode =  425, total_reward =  86.451 (best =   95.26), average_10 =   84.83, average_reward =   43.97, episode_steps =  81
# Episode =  426, total_reward =  89.330 (best =   95.26), average_10 =   85.72, average_reward =   44.08, episode_steps = 144
# Episode =  427, total_reward =  92.717 (best =   95.26), average_10 =   85.72, average_reward =   44.19, episode_steps =  84
# Episode =  428, total_reward =  90.640 (best =   95.26), average_10 =   85.63, average_reward =   44.30, episode_steps = 135
# Episode =  429, total_reward =  85.751 (best =   95.26), average_10 =   85.67, average_reward =   44.40, episode_steps = 186
# Episode =  430, total_reward =  84.680 (best =   95.26), average_10 =   86.30, average_reward =   44.49, episode_steps = 153
# Episode =  431, total_reward =  92.238 (best =   95.26), average_10 =   87.44, average_reward =   44.60, episode_steps =  87
# Episode =  432, total_reward =  84.250 (best =   95.26), average_10 =   88.11, average_reward =   44.69, episode_steps = 144
# Episode =  433, total_reward =  85.288 (best =   95.26), average_10 =   87.68, average_reward =   44.79, episode_steps = 186
# Episode =  434, total_reward =  83.702 (best =   95.26), average_10 =   87.50, average_reward =   44.88, episode_steps = 144
# Episode =  435, total_reward =  72.423 (best =   95.26), average_10 =   86.10, average_reward =   44.94, episode_steps = 276
# Episode =  436, total_reward =  59.347 (best =   95.26), average_10 =   83.10, average_reward =   44.97, episode_steps = 504
# Episode =  437, total_reward =  83.560 (best =   95.26), average_10 =   82.19, average_reward =   45.06, episode_steps = 201
# Episode =  438, total_reward =  86.251 (best =   95.26), average_10 =   81.75, average_reward =   45.16, episode_steps = 186
# Episode =  439, total_reward =  91.691 (best =   95.26), average_10 =   82.34, average_reward =   45.26, episode_steps = 144
# Episode =  440, total_reward =  71.240 (best =   95.26), average_10 =   81.00, average_reward =   45.32, episode_steps = 339
# Episode =  441, total_reward =  72.534 (best =   95.26), average_10 =   79.03, average_reward =   45.38, episode_steps = 273
# Episode =  442, total_reward =  59.602 (best =   95.26), average_10 =   76.56, average_reward =   45.42, episode_steps = 483
# Episode =  443, total_reward =  83.956 (best =   95.26), average_10 =   76.43, average_reward =   45.50, episode_steps = 198
# Episode =  444, total_reward =  48.887 (best =   95.26), average_10 =   72.95, average_reward =   45.51, episode_steps = 618
# Episode =  445, total_reward =  70.116 (best =   95.26), average_10 =   72.72, average_reward =   45.57, episode_steps = 294
# Episode =  446, total_reward =  86.804 (best =   95.26), average_10 =   75.46, average_reward =   45.66, episode_steps = 153
# Episode =  447, total_reward =  79.125 (best =   95.26), average_10 =   75.02, average_reward =   45.73, episode_steps = 189
# Episode =  448, total_reward =  82.194 (best =   95.26), average_10 =   74.61, average_reward =   45.81, episode_steps = 213
# Episode =  449, total_reward =  85.066 (best =   95.26), average_10 =   73.95, average_reward =   45.90, episode_steps = 138
# Episode =  450, total_reward =  61.241 (best =   95.26), average_10 =   72.95, average_reward =   45.94, episode_steps = 438
# Episode =  451, total_reward =  93.362 (best =   95.26), average_10 =   75.04, average_reward =   46.04, episode_steps =  75
# Episode =  452, total_reward =  83.004 (best =   95.26), average_10 =   77.38, average_reward =   46.12, episode_steps = 234
# Episode =  453, total_reward =  83.737 (best =   95.26), average_10 =   77.35, average_reward =   46.21, episode_steps = 141
# Episode =  454, total_reward =  89.729 (best =   95.26), average_10 =   81.44, average_reward =   46.30, episode_steps =  75
# Episode =  455, total_reward =  81.394 (best =   95.26), average_10 =   82.57, average_reward =   46.38, episode_steps = 321
# Episode =  456, total_reward =  78.942 (best =   95.26), average_10 =   81.78, average_reward =   46.45, episode_steps = 264
# Episode =  457, total_reward =  82.330 (best =   95.26), average_10 =   82.10, average_reward =   46.53, episode_steps = 252
# Episode =  458, total_reward =  84.651 (best =   95.26), average_10 =   82.35, average_reward =   46.61, episode_steps = 174
# Episode =  459, total_reward =  86.352 (best =   95.26), average_10 =   82.47, average_reward =   46.70, episode_steps = 147
# Episode =  460, total_reward =  89.880 (best =   95.26), average_10 =   85.34, average_reward =   46.79, episode_steps = 138
# Episode =  461, total_reward =  65.013 (best =   95.26), average_10 =   82.50, average_reward =   46.83, episode_steps = 471
# Episode =  462, total_reward =  86.343 (best =   95.26), average_10 =   82.84, average_reward =   46.92, episode_steps = 168
# Episode =  463, total_reward =  84.221 (best =   95.26), average_10 =   82.89, average_reward =   47.00, episode_steps = 204
# Episode =  464, total_reward =  87.447 (best =   95.26), average_10 =   82.66, average_reward =   47.08, episode_steps =  75
# Episode =  465, total_reward =  84.904 (best =   95.26), average_10 =   83.01, average_reward =   47.17, episode_steps = 141
# Episode =  466, total_reward =  77.091 (best =   95.26), average_10 =   82.82, average_reward =   47.23, episode_steps = 258
# Episode =  467, total_reward =  63.912 (best =   95.26), average_10 =   80.98, average_reward =   47.27, episode_steps = 420
# Episode =  468, total_reward =  75.929 (best =   95.26), average_10 =   80.11, average_reward =   47.33, episode_steps = 267
# Episode =  469, total_reward =  87.777 (best =   95.26), average_10 =   80.25, average_reward =   47.41, episode_steps = 150
# Episode =  470, total_reward =  75.353 (best =   95.26), average_10 =   78.80, average_reward =   47.47, episode_steps = 267
# Episode =  471, total_reward =  87.068 (best =   95.26), average_10 =   81.00, average_reward =   47.56, episode_steps = 132
# Episode =  472, total_reward =  65.014 (best =   95.26), average_10 =   78.87, average_reward =   47.59, episode_steps = 390
# Episode =  473, total_reward =  62.219 (best =   95.26), average_10 =   76.67, average_reward =   47.63, episode_steps = 447
# Episode =  474, total_reward =  48.533 (best =   95.26), average_10 =   72.78, average_reward =   47.63, episode_steps = 675
# Episode =  475, total_reward =  59.576 (best =   95.26), average_10 =   70.25, average_reward =   47.65, episode_steps = 357
# Episode =  476, total_reward =  64.084 (best =   95.26), average_10 =   68.95, average_reward =   47.69, episode_steps = 327
# Episode =  477, total_reward =  83.320 (best =   95.26), average_10 =   70.89, average_reward =   47.76, episode_steps = 192
# Episode =  478, total_reward =  89.521 (best =   95.26), average_10 =   72.25, average_reward =   47.85, episode_steps =  99
# Episode =  479, total_reward =  83.745 (best =   95.26), average_10 =   71.84, average_reward =   47.92, episode_steps = 216
# Episode =  480, total_reward =  87.150 (best =   95.26), average_10 =   73.02, average_reward =   48.01, episode_steps = 165
# Episode =  481, total_reward =  45.045 (best =   95.26), average_10 =   68.82, average_reward =   48.00, episode_steps = 768
# Episode =  482, total_reward =  92.799 (best =   95.26), average_10 =   71.60, average_reward =   48.09, episode_steps =  78
# Episode =  483, total_reward =  83.749 (best =   95.26), average_10 =   73.75, average_reward =   48.17, episode_steps = 198
# Episode =  484, total_reward =  90.505 (best =   95.26), average_10 =   77.95, average_reward =   48.25, episode_steps =  90
# Episode =  485, total_reward =  81.909 (best =   95.26), average_10 =   80.18, average_reward =   48.32, episode_steps = 204
# Episode =  486, total_reward =  78.301 (best =   95.26), average_10 =   81.60, average_reward =   48.38, episode_steps = 183
# Episode =  487, total_reward =  87.460 (best =   95.26), average_10 =   82.02, average_reward =   48.46, episode_steps =  75
# Episode =  488, total_reward =  87.315 (best =   95.26), average_10 =   81.80, average_reward =   48.54, episode_steps = 138
# Episode =  489, total_reward =  78.009 (best =   95.26), average_10 =   81.22, average_reward =   48.60, episode_steps = 177
# Episode =  490, total_reward =  75.793 (best =   95.26), average_10 =   80.09, average_reward =   48.66, episode_steps = 264
# Episode =  491, total_reward =  85.094 (best =   95.26), average_10 =   84.09, average_reward =   48.73, episode_steps = 129
# Episode =  492, total_reward =  87.419 (best =   95.26), average_10 =   83.56, average_reward =   48.81, episode_steps = 138
# Episode =  493, total_reward =  86.003 (best =   95.26), average_10 =   83.78, average_reward =   48.89, episode_steps = 135
# Episode =  494, total_reward =  82.633 (best =   95.26), average_10 =   82.99, average_reward =   48.96, episode_steps = 159
# Episode =  495, total_reward =  80.707 (best =   95.26), average_10 =   82.87, average_reward =   49.02, episode_steps = 180
# Episode =  496, total_reward =  72.809 (best =   95.26), average_10 =   82.32, average_reward =   49.07, episode_steps = 267
# Episode =  497, total_reward =  84.278 (best =   95.26), average_10 =   82.01, average_reward =   49.14, episode_steps = 135
# Episode =  498, total_reward =  80.874 (best =   95.26), average_10 =   81.36, average_reward =   49.20, episode_steps = 183
# Episode =  499, total_reward =  78.324 (best =   95.26), average_10 =   81.39, average_reward =   49.26, episode_steps = 183
# Episode =  500, total_reward =  89.509 (best =   95.26), average_10 =   82.76, average_reward =   49.34, episode_steps = 144
# Gamma = 0.7 theta= 0.15 sigma= 0.2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Plot the rewards
plt.plot(rewards_data['episode'], rewards_data['total_reward'])
plt.plot(rewards_data['episode'], rewards_data['running_average'])
plt.plot(rewards_data['episode'], rewards_data['average_reward'])
plt.show()
#_ = plt.ylim()

# %% [markdown]
# After much testing and modifying agent architecture and hyperparameters, my agent has achieved some reasonable level of performance that demonstrates it is being able to learn this task. The agent should be ready to tackle the quadcopter.
#
# To simplify the quadcopter task below, I have set all rotors to the same value, so that the quadcopter can only move in the vertical direction. To visualise the quadcopter, I have adapted the render() function from OpenAI's CartPole environment.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import pandas as pd
import numpy as np
import math
from agents.agent import DDPG
from task import TakeOffTask
import csv

num_episodes = 200

task = TakeOffTask()
agent = DDPG(task, gamma=0.99, theta=0.15, sigma=0.2)

labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1']#, 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
all_results = []
rewards_data = {x : [] for x in ['episode', 'total_reward', 'running_average', 'average_reward']}

best_total_reward = -math.inf
average_reward = 0
average_10 = 0

rotor_low = task.rotor_low
rotor_range = task.rotor_range

for i_episode in range(1, num_episodes+1):
    
    state = agent.reset_episode() # start a new episode
    total_reward = 0
    episode_steps = 0
    results = {x : [] for x in labels}
    task.render()
    
    while True:
        action = agent.act(state)
        action_level = (action[0] - task.action_low)/task.action_range
        rotor_speed = rotor_low + action_level * rotor_range
        next_state, reward, done = task.step(rotor_speed)
        task.render()
        episode_steps += 1  
        total_reward += reward
        agent.step(action, reward, next_state, done)
        state = next_state
        
        
        to_save = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + [rotor_speed] #+ list(action)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_save[ii])
            
        if done:

            if total_reward > best_total_reward:
                best_total_reward = total_reward
            average_reward = (average_reward*(i_episode - 1) + total_reward)/i_episode        
            rewards_data['episode'].append(i_episode)
            rewards_data['total_reward'].append(total_reward)
            average_10 = sum(rewards_data['total_reward'][i_episode-10:i_episode])/10
            rewards_data['running_average'].append(average_10)
            rewards_data['average_reward'].append(average_reward)
            print("\rEpisode = {:4d}, total_reward = {:5.1f} (best = {:5.1f}), average_10 = {:5.1f}, average_reward = {:5.1f}, episode_steps = {:2d}".format(i_episode, total_reward, best_total_reward, average_10, average_reward, episode_steps))
            #print("\rEpisode = {:4d}, total_reward = {:7.3f} (best = {:7.3f}), episode_steps = {:4d}".format(i_episode, total_reward, best_total_reward, episode_steps))
            all_results.append(results)
            break
    sys.stdout.flush()
task.close()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Episode =    1, total_reward = -100.0 (best = -100.0), average_10 = -10.0, average_reward = -100.0, episode_steps =  1
# Episode =    2, total_reward = -100.0 (best = -100.0), average_10 = -20.0, average_reward = -100.0, episode_steps =  1
# Episode =    3, total_reward = -100.0 (best = -100.0), average_10 = -30.0, average_reward = -100.0, episode_steps =  1
# Episode =    4, total_reward = -100.0 (best = -100.0), average_10 = -40.0, average_reward = -100.0, episode_steps =  1
# Episode =    5, total_reward = -100.0 (best = -100.0), average_10 = -50.0, average_reward = -100.0, episode_steps =  1
# Episode =    6, total_reward = -100.0 (best = -100.0), average_10 = -40.0, average_reward = -100.0, episode_steps =  1
# Episode =    7, total_reward =  35.5 (best =  35.5), average_10 = -16.4, average_reward = -80.6, episode_steps = 84
# Episode =    8, total_reward = -100.0 (best =  35.5), average_10 =  -6.4, average_reward = -83.1, episode_steps =  8
# Episode =    9, total_reward = -100.0 (best =  35.5), average_10 = -10.0, average_reward = -84.9, episode_steps =  5
# Episode =   10, total_reward = -100.0 (best =  35.5), average_10 = -86.4, average_reward = -86.4, episode_steps =  3
# Episode =   11, total_reward =  60.8 (best =  60.8), average_10 = -70.4, average_reward = -73.1, episode_steps = 84
# Episode =   12, total_reward = -100.0 (best =  60.8), average_10 = -70.4, average_reward = -75.3, episode_steps =  1
# Episode =   13, total_reward =  69.6 (best =  69.6), average_10 = -53.4, average_reward = -64.2, episode_steps = 84
# Episode =   14, total_reward = -100.0 (best =  69.6), average_10 = -53.4, average_reward = -66.7, episode_steps =  1
# Episode =   15, total_reward =  94.8 (best =  94.8), average_10 = -33.9, average_reward = -56.0, episode_steps = 84
# Episode =   16, total_reward =  94.8 (best =  94.8), average_10 = -14.4, average_reward = -46.5, episode_steps = 84
# Episode =   17, total_reward =  79.7 (best =  94.8), average_10 = -10.0, average_reward = -39.1, episode_steps = 84
# Episode =   18, total_reward =  95.7 (best =  95.7), average_10 =   9.5, average_reward = -31.6, episode_steps = 84
# Episode =   19, total_reward =  98.5 (best =  98.5), average_10 =  29.4, average_reward = -24.8, episode_steps = 84
# Episode =   20, total_reward =  89.6 (best =  98.5), average_10 =  48.3, average_reward = -19.0, episode_steps = 84
# Episode =   21, total_reward =  80.0 (best =  98.5), average_10 =  50.3, average_reward = -14.3, episode_steps = 84
# Episode =  192, total_reward =  77.4 (best =  99.6), average_10 =  86.4, average_reward =  76.6, episode_steps = 84
# Episode =  193, total_reward =  91.1 (best =  99.6), average_10 =  85.8, average_reward =  76.6, episode_steps = 84
# Episode =  194, total_reward =  83.6 (best =  99.6), average_10 =  85.2, average_reward =  76.7, episode_steps = 84
# Episode =  195, total_reward =  72.3 (best =  99.6), average_10 =  84.5, average_reward =  76.6, episode_steps = 84
# Episode =  196, total_reward =  91.6 (best =  99.6), average_10 =  84.0, average_reward =  76.7, episode_steps = 84
# Episode =  197, total_reward =  95.5 (best =  99.6), average_10 =  85.4, average_reward =  76.8, episode_steps = 84
# Episode =  198, total_reward =  97.5 (best =  99.6), average_10 =  86.2, average_reward =  76.9, episode_steps = 84
# Episode =  199, total_reward =  74.7 (best =  99.6), average_10 =  87.0, average_reward =  76.9, episode_steps = 84
# Episode =  200, total_reward =  86.9 (best =  99.6), average_10 =  85.8, average_reward =  77.0, episode_steps = 84

# %% [markdown]
# ## Plot the Rewards
#
# Once you are satisfied with your performance, plot the episode rewards, either from a single run, or averaged over multiple runs.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Plot the rewards
plt.plot(rewards_data['episode'], rewards_data['total_reward'])
plt.plot(rewards_data['episode'], rewards_data['running_average'])
plt.plot(rewards_data['episode'], rewards_data['average_reward'])
plt.show()

# %% [markdown]
# ## Reflections
#
# **Question 1**: Describe the task that you specified in `task.py`.  How did you design the reward function?
#
# **Answer**: I have designed the task for the quadcopter to take off and finish the episode at a height as close to 100m as possible. The reward function attributed rewards only at the end of the episode, as follows: -100 if the episode ends before the specified runtime (i.e. if the quadcopter crashes), and 100 minus the distance between the quadcopter otherwise. This seems to have worked reasonably to the desired end, as we can verify with the visualisations.

# %% [markdown]
# **Question 2**: Discuss your agent briefly, using the following questions as a guide:
#
# - What learning algorithm(s) did you try? What worked best for you?
# - What was your final choice of hyperparameters (such as $\alpha$, $\gamma$, $\epsilon$, etc.)?
# - What neural network architecture did you use (if any)? Specify layers, sizes, activation functions, etc.
#
# **Answer**: I have used the DDPG learning algorithm, following the sample code provided on the course website. I have played around with several different types of architectures. I have found that the architecture that worked best for me had:
# - For the actor model: three dense layers with 100, 200, 100 units, each one followed by relu activation layers.
# - For the critic model: 1 dense layer with 100 units for the states and actions pathways, followed by relu activation, then another two dense layers with 200 and 100 units after adding the two pathways.
# I have tried to use dropout, batch normalisation, and different kinds of regularizers, but perhaps surprisingly none of those seemed to have any appreciable effect on the results or even the training speed.
#
# I followed Lilicrap et al (2016) for the learning rates of 0.0001 and 0.001 for the actor and critic models, respectively, and soft update parameter $\tau = 0.001$. I've found best results with the buffer size of 100000 and batch size of 256. I've tried changing the values for the discount factor $\gamma$ but 0.99 seemed to give the best results. The noise parameters were best at $\theta=0.15$ and $\sigma=0.2$ as in the original code. I have also tried to modify the noise function to add an envelope for an exponential decay in the noise amplitude, but that didn't seem to help either.

# %% [markdown]
# **Question 3**: Using the episode rewards plot, discuss how the agent learned over time.
#
# - Was it an easy task to learn or hard?
# - Was there a gradual learning curve, or an aha moment?
# - How good was the final performance of the agent? (e.g. mean rewards over the last 10 episodes)
#
# **Answer**: It was quite hard to find a reward function that worked well. For the reward function I've settled with, the learning curve oscillates for a while at low values as the quadcopter keeps crashing or reaching low heights, and then settles at a peak value close 85 (out of a maximum value of 100), with small oscillations. That's quite a reasonable performance.

# %% [markdown]
# **Question 4**: Briefly summarize your experience working on this project. You can use the following prompts for ideas.
#
# - What was the hardest part of the project? (e.g. getting started, plotting, specifying the task, etc.)
# - Did you find anything interesting in how the quadcopter or your agent behaved?
#
# **Answer**: Getting started was quite hard, but after I had written the basic code, it turned out to be very hard to find a reasonable reward function that worked, even after simplifying the problem by setting all rotors to the same value. This led me to test my agent with the ContinuousMountainCar environment, which showed that the agent was learning reasonably well, and thus that the problem was more about designing good reward functions for the task at hand.
#
# I have found an error in the PhysicsSim code: the air resistance force was set up to always be negative (i.e. pointing down in the z axis), even when the quadcopter has a velocity in the -z direction (in which case the air resistance should point in the +z direction). This was causing a runaway behaviour if the quadcopter started moving downwards with any appreciable velocity. I have modified the physics_sym.py to fix this.
